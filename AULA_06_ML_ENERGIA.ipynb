# %% [markdown]
# <a href="https://colab.research.google.com/github/leofigueredo2008-beep/SERS_FIAP/blob/main/AULA_06_ML_ENERGIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Exercicios
#
# Treinar um modelo preditivo de classificação da estabilidade de uma rede elétrica
#
# Fonte:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Machine Learning
# Algoritmos  do sklearn para classificação
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# Separação de dados de treino e teste
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test

#metricas para classificação
from sklearn.metrics import accuracy_score #acuracia
from sklearn.metrics import confusion_matrix #identificação onde o modelo errou
from sklearn.metrics import classification_report #resumo de metricas

# %% [markdown]
# carregar os dados e gerar um DataFrame

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/leofigueredo2008-beep/SERS_FIAP/refs/heads/main/Data_for_UCI_named.csv')
dados.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %% [markdown]
# ##Analise exploratoria

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
#Somente estatisticas de atributos numericos
dados.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# std        0.433035      0.433035      0.433035      0.274256      0.274255
# min       -1.999891     -1.999945     -1.999926      0.050009      0.050053
# 25%       -1.624901     -1.625025     -1.624960      0.287521      0.287552
# 50%       -1.249966     -1.249974     -1.250007      0.525009      0.525003
# 75%       -0.874977     -0.875043     -0.875065      0.762435      0.762490
# max       -0.500108     -0.500072     -0.500025      0.999937      0.999944
#
#                  g3            g4          stab
# count  10000.000000  10000.000000  10000.000000
# mean       0.525000      0.525000      0.015731
# std        0.274255      0.274255      0.036919
# min        0.050054      0.050028     -0.080760
# 25%        0.287514      0.287494     -0.015557
# 50%        0.525015      0.525002      0.017142
# 75%        0.762440      0.762433      0.044878
# max        0.999982      0.999930      0.109403

# %%
#Somente estatisticas de atributos categoricos
dados.describe(include='object')
# Out:
#            stabf
# count      10000
# unique         2
# top     unstable
# freq        6380

# %%
#Checando a quantidade de classes da coluna alvo (stabf)
dados['stabf'].unique()
# Out:
# array(['unstable', 'stable'], dtype=object)

# %%
#Checando a quantidade de valores de cada classe da coluna alvo
dados['stabf'].value_counts()
# Out:
# stabf
# unstable    6380
# stable      3620
# Name: count, dtype: int64

# %% [markdown]
# ## Separação de dados de
# entrada (features) -> X
# saída (targe) -> y

# %%
#features
X = dados.drop(['stab', 'stabf'], axis=1)
X.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923

# %%
#Variavel alvo target
y = dados['stabf']
y.head()
# Out:
# 0    unstable
# 1      stable
# 2    unstable
# 3    unstable
# 4    unstable
# Name: stabf, dtype: object

# %%
#Renomeando as classes da coluna alvo
y = y.map({'stable': 'estavel', 'unstable': 'instavel'})
y.head()
# Out:
# 0    instavel
# 1     estavel
# 2    instavel
# 3    instavel
# 4    instavel
# Name: stabf, dtype: object

# %% [markdown]
# ##Separação de dados de treino e teste

# %%
## X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=17)

# %% [markdown]
# ## Treinamento e gração das previsões do modelo

# %%
#Instanciando o modelo
modelo_LR = LogisticRegression()
# Treinando o modelo
modelo_LR.fit(X_train, y_train)
# Gerando previsões
y_predict = modelo_LR.predict(X_test)
y_predict
# Out:
# array(['instavel', 'instavel', 'instavel', ..., 'estavel', 'instavel',
#        'instavel'], dtype=object)

# %% [markdown]
# ##Avaliação do modelo

# %%
#Acuracia
acuracia = 100 * accuracy_score(y_test, y_predict)
print(f'A acuracia do modelo baseado em regressão logistica é: {acuracia:.2f} %')
# Out:
# A acuracia do modelo baseado em regressão logistica é: 82.45 %

# %%
# Matriz de confusão usando o seaborn e matplotlib

# %%
cm = confusion_matrix(y_test, y_predict)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.title('Matriz de Confusão')
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.show()

# %%
#Classificação report  usando seaborn e matplotlib
report = classification_report(y_test, y_predict)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#      estavel       0.78      0.73      0.75       725
#     instavel       0.85      0.88      0.86      1275
#
#     accuracy                           0.82      2000
#    macro avg       0.81      0.80      0.81      2000
# weighted avg       0.82      0.82      0.82      2000

# %% [markdown]
# ##Exercício 2

# %%
from sklearn.linear_model import LinearRegression

# %%
#Instanciando o modelo com base na classe  LinearRegression
modelo_LR = LinearRegression()

# %%
dados.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
#Features --> 3 atributos que tenham maior correlação linear com a coluna alvo (target) -> 'Stab'
y = dados['stab']
y.head()
# Out:
# 0    0.055347
# 1   -0.005957
# 2    0.003471
# 3    0.028871
# 4    0.049860
# Name: stab, dtype: float64

# %%
#Gemini Part (Selecionando os tres atributos )
correlation_matrix = dados.corr(numeric_only=True)

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação de Atributos')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6), facecolor='black')

# Set general style for the plots
sns.set_style('darkgrid', {'axes.facecolor': 'black', 'grid.color': 'gray', 'text.color': 'white'})
plt.rcParams.update({'text.color': 'white', 'axes.labelcolor': 'white', 'xtick.color': 'white', 'ytick.color': 'white'})

# Feature tau2
sns.regplot(x='tau2', y='stab', data=dados, ax=axes[0], scatter_kws={'alpha':0.3, 'color':'cyan'}, line_kws={'color':'red'})
axes[0].set_title('Correlação entre tau2 e stab', color='white')
axes[0].set_xlabel('tau2', color='white')
axes[0].set_ylabel('stab', color='white')

# Feature g2
sns.regplot(x='g2', y='stab', data=dados, ax=axes[1], scatter_kws={'alpha':0.3, 'color':'cyan'}, line_kws={'color':'red'})
axes[1].set_title('Correlação entre g2 e stab', color='white')
axes[1].set_xlabel('g2', color='white')
axes[1].set_ylabel('stab', color='white')

# Feature g3
sns.regplot(x='g3', y='stab', data=dados, ax=axes[2], scatter_kws={'alpha':0.3, 'color':'cyan'}, line_kws={'color':'red'})
axes[2].set_title('Correlação entre g3 e stab', color='white')
axes[2].set_xlabel('g3', color='white')
axes[2].set_ylabel('stab', color='white')

plt.tight_layout()
plt.show()
